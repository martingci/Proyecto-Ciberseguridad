# %% [markdown]
# # Generación de archivos con Miner

# %% [markdown]
# ## Se definen las rutas a utilizar

# %%
from pathlib import Path


RUTA_BASE = Path.cwd().parent
RUTA_REPOS = RUTA_BASE / "miner" / "repos"
RUTA_RESULTADOS = RUTA_BASE / "results"

# %% [markdown]
# ## Paso 1: Obtener y clonar repositorios de Github

# %%
from generate_github_api import GetReposGitHubAPI

github_org = "vercel"
cantidad_repos = 25
github_api = GetReposGitHubAPI(str(RUTA_REPOS), github_org)
github_api.run(cantidad_repos)
# Out:
# El repositorio next.js ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/next.js. Saltando clonación.
# El repositorio hyper ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/hyper. Saltando clonación.
# El repositorio swr ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/swr. Saltando clonación.
# El repositorio pkg ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/pkg. Saltando clonación.
# El repositorio ai ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/ai. Saltando clonación.
# El repositorio chatbot ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/chatbot. Saltando clonación.
# El repositorio vercel ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/vercel. Saltando clonación.
# El repositorio commerce ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/commerce. Saltando clonación.
# El repositorio satori ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/satori. Saltando clonación.
# El repositorio micro ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/micro. Saltando clonación.
# El repositorio serve ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/serve. Saltando clonación.
# El repositorio ncc ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/ncc. Saltando clonación.
# El repositorio styled-jsx ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/styled-jsx. Saltando clonación.
# El repositorio nextjs-subscription-payments ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/nextjs-subscription-payments. Saltando clonación.
# El repositorio next-forge ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/next-forge. Saltando clonación.
# El repositorio platforms ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/platforms. Saltando clonación.
# El repositorio ms ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/ms. Saltando clonación.
# El repositorio streamdown ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/streamdown. Saltando clonación.
# El repositorio examples ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/examples. Saltando clonación.
# El repositorio next-learn ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/next-learn. Saltando clonación.
# El repositorio og-image ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/og-image. Saltando clonación.
# El repositorio release ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/release. Saltando clonación.
# El repositorio hazel ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/hazel. Saltando clonación.
# El repositorio next-app-router-playground ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/next-app-router-playground. Saltando clonación.
# El repositorio kirimase ya existe en /workspaces/Proyecto-Ciberseguridad/miner/repos/kirimase. Saltando clonación.

# %% [markdown]
# ## Paso 2: Generar SBOMs con Syft

# %%
from generate_sboms import SBOMGenerator

sbom_generator = SBOMGenerator(str(RUTA_REPOS), str(RUTA_RESULTADOS))
sbom_generator.run()
# Out:
# INFO | Usando Syft CLI: /usr/local/bin/syft
# INFO | [1/25] Procesando repositorio miner/repos/ai
# INFO | SBOM guardado en results/ai-sbom.json
# INFO | [2/25] Procesando repositorio miner/repos/chatbot
# INFO | SBOM guardado en results/chatbot-sbom.json
# INFO | [3/25] Procesando repositorio miner/repos/commerce
# INFO | SBOM guardado en results/commerce-sbom.json
# INFO | [4/25] Procesando repositorio miner/repos/examples
# INFO | SBOM guardado en results/examples-sbom.json
# INFO | [5/25] Procesando repositorio miner/repos/hazel
# INFO | SBOM guardado en results/hazel-sbom.json
# INFO | [6/25] Procesando repositorio miner/repos/hyper
# INFO | SBOM guardado en results/hyper-sbom.json
# INFO | [7/25] Procesando repositorio miner/repos/kirimase
# INFO | SBOM guardado en results/kirimase-sbom.json
# INFO | [8/25] Procesando repositorio miner/repos/micro
# INFO | SBOM guardado en results/micro-sbom.json
# INFO | [9/25] Procesando repositorio miner/repos/ms
# INFO | SBOM guardado en results/ms-sbom.json
# INFO | [10/25] Procesando repositorio miner/repos/ncc
# INFO | SBOM guardado en results/ncc-sbom.json
# INFO | [11/25] Procesando repositorio miner/repos/next-app-router-playground
# INFO | SBOM guardado en results/next-app-router-playground-sbom.json
# INFO | [12/25] Procesando repositorio miner/repos/next-forge
# INFO | SBOM guardado en results/next-forge-sbom.json
# INFO | [13/25] Procesando repositorio miner/repos/next-learn
# INFO | SBOM guardado en results/next-learn-sbom.json
# INFO | [14/25] Procesando repositorio miner/repos/next.js
# INFO | SBOM guardado en results/next.js-sbom.json
# INFO | [15/25] Procesando repositorio miner/repos/nextjs-subscription-payments
# INFO | SBOM guardado en results/nextjs-subscription-payments-sbom.json
# INFO | [16/25] Procesando repositorio miner/repos/og-image
# INFO | SBOM guardado en results/og-image-sbom.json
# INFO | [17/25] Procesando repositorio miner/repos/pkg
# INFO | SBOM guardado en results/pkg-sbom.json
# INFO | [18/25] Procesando repositorio miner/repos/platforms
# INFO | SBOM guardado en results/platforms-sbom.json
# INFO | [19/25] Procesando repositorio miner/repos/release
# INFO | SBOM guardado en results/release-sbom.json
# INFO | [20/25] Procesando repositorio miner/repos/satori
# INFO | SBOM guardado en results/satori-sbom.json
# INFO | [21/25] Procesando repositorio miner/repos/serve
# INFO | SBOM guardado en results/serve-sbom.json
# INFO | [22/25] Procesando repositorio miner/repos/streamdown
# INFO | SBOM guardado en results/streamdown-sbom.json
# INFO | [23/25] Procesando repositorio miner/repos/styled-jsx
# INFO | SBOM guardado en results/styled-jsx-sbom.json
# INFO | [24/25] Procesando repositorio miner/repos/swr
# INFO | SBOM guardado en results/swr-sbom.json
# INFO | [25/25] Procesando repositorio miner/repos/vercel
# INFO | SBOM guardado en results/vercel-sbom.json
# INFO | Resumen final | total_repos=25 | repos_generados=25 | archivos_generados=25 | omitidos=0 | errores=0

# %% [markdown]
# ## Paso 3: Analizar con CodeQL

# %%
from generate_codeql import CodeQLAnalyzer

codeql_analyzer = CodeQLAnalyzer(str(RUTA_REPOS), str(RUTA_RESULTADOS))
codeql_analyzer.run()
codeql_analyzer.run_cicd_analysis()
# Out:
# INFO | Usando CodeQL CLI: /usr/local/bin/codeql
# INFO | === Diagnóstico del Entorno CodeQL ===
# INFO | ✓ CodeQL CLI: CodeQL command-line toolchain release 2.25.1.
# INFO | ✓ Node.js: v20.20.2
# INFO | ✓ npm: 10.8.2
# INFO | Verificando query packs...
# INFO | ✓ Query pack codeql/python-queries disponible
# INFO | ✓ Query pack codeql/javascript-queries disponible
# INFO | ✓ Query pack codeql/java-queries disponible
# INFO | ✓ Query pack codeql/actions-queries disponible
# INFO | === Fin Diagnóstico ===
#
# INFO | [1/25] Procesando repositorio miner/repos/ai
# INFO | Lenguaje detectado en ai: javascript
# INFO | Directorio temporal CodeQL: /tmp/codeql_analysis
# INFO | Creando base de datos CodeQL para ai (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/ai_temp.sarif (4651747 bytes)
# INFO | SARIF output length: 4651747 bytes
# INFO | parse_sarif: recibiendo 4651747 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 840 resultados en run[0]
# INFO | parse_sarif: total_issues=840
# INFO | save_analysis: ai con 840 issues
# INFO | Analisis CodeQL guardado en results/ai-codeql.json
# INFO | [2/25] Procesando repositorio miner/repos/chatbot
# INFO | Lenguaje detectado en chatbot: javascript
# INFO | Creando base de datos CodeQL para chatbot (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/chatbot_temp.sarif (286699 bytes)
# INFO | SARIF output length: 286699 bytes
# INFO | parse_sarif: recibiendo 286699 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 3 resultados en run[0]
# INFO | parse_sarif: total_issues=3
# INFO | save_analysis: chatbot con 3 issues
# INFO | Analisis CodeQL guardado en results/chatbot-codeql.json
# INFO | [3/25] Procesando repositorio miner/repos/commerce
# INFO | Lenguaje detectado en commerce: javascript
# INFO | Creando base de datos CodeQL para commerce (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/commerce_temp.sarif (197314 bytes)
# INFO | SARIF output length: 197314 bytes
# INFO | parse_sarif: recibiendo 197314 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 0 resultados en run[0]
# INFO | parse_sarif: total_issues=0
# INFO | save_analysis: commerce con 0 issues
# INFO | Analisis CodeQL guardado en results/commerce-codeql.json
# INFO | [4/25] Procesando repositorio miner/repos/examples
# INFO | Lenguaje detectado en examples: javascript
# INFO | Creando base de datos CodeQL para examples (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/examples_temp.sarif (3044502 bytes)
# INFO | SARIF output length: 3044502 bytes
# INFO | parse_sarif: recibiendo 3044502 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 155 resultados en run[0]
# INFO | parse_sarif: total_issues=155
# INFO | save_analysis: examples con 155 issues
# INFO | Analisis CodeQL guardado en results/examples-codeql.json
# INFO | [5/25] Procesando repositorio miner/repos/hazel
# INFO | Lenguaje detectado en hazel: javascript
# INFO | Creando base de datos CodeQL para hazel (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/hazel_temp.sarif (160810 bytes)
# INFO | SARIF output length: 160810 bytes
# INFO | parse_sarif: recibiendo 160810 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 0 resultados en run[0]
# INFO | parse_sarif: total_issues=0
# INFO | save_analysis: hazel con 0 issues
# INFO | Analisis CodeQL guardado en results/hazel-codeql.json
# INFO | [6/25] Procesando repositorio miner/repos/hyper
# INFO | Lenguaje detectado en hyper: javascript
# INFO | Creando base de datos CodeQL para hyper (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/hyper_temp.sarif (660784 bytes)
# INFO | SARIF output length: 660784 bytes
# INFO | parse_sarif: recibiendo 660784 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 673 resultados en run[0]
# INFO | parse_sarif: total_issues=673
# INFO | save_analysis: hyper con 673 issues
# INFO | Analisis CodeQL guardado en results/hyper-codeql.json
# INFO | [7/25] Procesando repositorio miner/repos/kirimase
# INFO | Lenguaje detectado en kirimase: javascript
# INFO | Creando base de datos CodeQL para kirimase (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/kirimase_temp.sarif (236008 bytes)
# INFO | SARIF output length: 236008 bytes
# INFO | parse_sarif: recibiendo 236008 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 76 resultados en run[0]
# INFO | parse_sarif: total_issues=76
# INFO | save_analysis: kirimase con 76 issues
# INFO | Analisis CodeQL guardado en results/kirimase-codeql.json
# INFO | [8/25] Procesando repositorio miner/repos/micro
# INFO | Lenguaje detectado en micro: javascript
# INFO | Creando base de datos CodeQL para micro (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/micro_temp.sarif (181078 bytes)
# INFO | SARIF output length: 181078 bytes
# INFO | parse_sarif: recibiendo 181078 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 5 resultados en run[0]
# INFO | parse_sarif: total_issues=5
# INFO | save_analysis: micro con 5 issues
# INFO | Analisis CodeQL guardado en results/micro-codeql.json
# INFO | [9/25] Procesando repositorio miner/repos/ms
# INFO | Lenguaje detectado en ms: javascript
# INFO | Creando base de datos CodeQL para ms (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/ms_temp.sarif (160223 bytes)
# INFO | SARIF output length: 160223 bytes
# INFO | parse_sarif: recibiendo 160223 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 0 resultados en run[0]
# INFO | parse_sarif: total_issues=0
# INFO | save_analysis: ms con 0 issues
# INFO | Analisis CodeQL guardado en results/ms-codeql.json
# INFO | [10/25] Procesando repositorio miner/repos/ncc
# INFO | Lenguaje detectado en ncc: javascript
# INFO | Creando base de datos CodeQL para ncc (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/ncc_temp.sarif (345615 bytes)
# INFO | SARIF output length: 345615 bytes
# INFO | parse_sarif: recibiendo 345615 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 63 resultados en run[0]
# INFO | parse_sarif: total_issues=63
# INFO | save_analysis: ncc con 63 issues
# INFO | Analisis CodeQL guardado en results/ncc-codeql.json
# INFO | [11/25] Procesando repositorio miner/repos/next-app-router-playground
# INFO | Lenguaje detectado en next-app-router-playground: javascript
# INFO | Creando base de datos CodeQL para next-app-router-playground (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/next-app-router-playground_temp.sarif (251418 bytes)
# INFO | SARIF output length: 251418 bytes
# INFO | parse_sarif: recibiendo 251418 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 1 resultados en run[0]
# INFO | parse_sarif: total_issues=1
# INFO | save_analysis: next-app-router-playground con 1 issues
# INFO | Analisis CodeQL guardado en results/next-app-router-playground-codeql.json
# INFO | [12/25] Procesando repositorio miner/repos/next-forge
# INFO | Lenguaje detectado en next-forge: javascript
# INFO | Creando base de datos CodeQL para next-forge (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/next-forge_temp.sarif (445710 bytes)
# INFO | SARIF output length: 445710 bytes
# INFO | parse_sarif: recibiendo 445710 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 5 resultados en run[0]
# INFO | parse_sarif: total_issues=5
# INFO | save_analysis: next-forge con 5 issues
# INFO | Analisis CodeQL guardado en results/next-forge-codeql.json
# INFO | [13/25] Procesando repositorio miner/repos/next-learn
# INFO | Lenguaje detectado en next-learn: javascript
# INFO | Creando base de datos CodeQL para next-learn (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/next-learn_temp.sarif (262743 bytes)
# INFO | SARIF output length: 262743 bytes
# INFO | parse_sarif: recibiendo 262743 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 13 resultados en run[0]
# INFO | parse_sarif: total_issues=13
# INFO | save_analysis: next-learn con 13 issues
# INFO | Analisis CodeQL guardado en results/next-learn-codeql.json
# INFO | [14/25] Procesando repositorio miner/repos/next.js
# INFO | Lenguaje detectado en next.js: javascript
# INFO | Creando base de datos CodeQL para next.js (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/next.js_temp.sarif (26854402 bytes)
# INFO | SARIF output length: 26854402 bytes
# INFO | parse_sarif: recibiendo 26854402 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 3976 resultados en run[0]
# INFO | parse_sarif: total_issues=3976
# INFO | save_analysis: next.js con 3976 issues
# INFO | Analisis CodeQL guardado en results/next.js-codeql.json
# INFO | [15/25] Procesando repositorio miner/repos/nextjs-subscription-payments
# INFO | Lenguaje detectado en nextjs-subscription-payments: javascript
# INFO | Creando base de datos CodeQL para nextjs-subscription-payments (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/nextjs-subscription-payments_temp.sarif (194223 bytes)
# INFO | SARIF output length: 194223 bytes
# INFO | parse_sarif: recibiendo 194223 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 7 resultados en run[0]
# INFO | parse_sarif: total_issues=7
# INFO | save_analysis: nextjs-subscription-payments con 7 issues
# INFO | Analisis CodeQL guardado en results/nextjs-subscription-payments-codeql.json
# INFO | [16/25] Procesando repositorio miner/repos/og-image
# INFO | Lenguaje detectado en og-image: javascript
# INFO | Creando base de datos CodeQL para og-image (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/og-image_temp.sarif (159103 bytes)
# INFO | SARIF output length: 159103 bytes
# INFO | parse_sarif: recibiendo 159103 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 0 resultados en run[0]
# INFO | parse_sarif: total_issues=0
# INFO | save_analysis: og-image con 0 issues
# INFO | Analisis CodeQL guardado en results/og-image-codeql.json
# INFO | [17/25] Procesando repositorio miner/repos/pkg
# INFO | Lenguaje detectado en pkg: javascript
# INFO | Creando base de datos CodeQL para pkg (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/pkg_temp.sarif (1030930 bytes)
# INFO | SARIF output length: 1030930 bytes
# INFO | parse_sarif: recibiendo 1030930 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 41 resultados en run[0]
# INFO | parse_sarif: total_issues=41
# INFO | save_analysis: pkg con 41 issues
# INFO | Analisis CodeQL guardado en results/pkg-codeql.json
# INFO | [18/25] Procesando repositorio miner/repos/platforms
# INFO | Lenguaje detectado en platforms: javascript
# INFO | Creando base de datos CodeQL para platforms (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/platforms_temp.sarif (167389 bytes)
# INFO | SARIF output length: 167389 bytes
# INFO | parse_sarif: recibiendo 167389 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 0 resultados en run[0]
# INFO | parse_sarif: total_issues=0
# INFO | save_analysis: platforms con 0 issues
# INFO | Analisis CodeQL guardado en results/platforms-codeql.json
# INFO | [19/25] Procesando repositorio miner/repos/release
# INFO | Lenguaje detectado en release: javascript
# INFO | Creando base de datos CodeQL para release (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/release_temp.sarif (161029 bytes)
# INFO | SARIF output length: 161029 bytes
# INFO | parse_sarif: recibiendo 161029 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 0 resultados en run[0]
# INFO | parse_sarif: total_issues=0
# INFO | save_analysis: release con 0 issues
# INFO | Analisis CodeQL guardado en results/release-codeql.json
# INFO | [20/25] Procesando repositorio miner/repos/satori
# INFO | Lenguaje detectado en satori: javascript
# INFO | Creando base de datos CodeQL para satori (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/satori_temp.sarif (355918 bytes)
# INFO | SARIF output length: 355918 bytes
# INFO | parse_sarif: recibiendo 355918 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 13 resultados en run[0]
# INFO | parse_sarif: total_issues=13
# INFO | save_analysis: satori con 13 issues
# INFO | Analisis CodeQL guardado en results/satori-codeql.json
# INFO | [21/25] Procesando repositorio miner/repos/serve
# INFO | Lenguaje detectado en serve: javascript
# INFO | Creando base de datos CodeQL para serve (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/serve_temp.sarif (169537 bytes)
# INFO | SARIF output length: 169537 bytes
# INFO | parse_sarif: recibiendo 169537 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 1 resultados en run[0]
# INFO | parse_sarif: total_issues=1
# INFO | save_analysis: serve con 1 issues
# INFO | Analisis CodeQL guardado en results/serve-codeql.json
# INFO | [22/25] Procesando repositorio miner/repos/streamdown
# INFO | Lenguaje detectado en streamdown: javascript
# INFO | Creando base de datos CodeQL para streamdown (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/streamdown_temp.sarif (392013 bytes)
# INFO | SARIF output length: 392013 bytes
# INFO | parse_sarif: recibiendo 392013 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 2 resultados en run[0]
# INFO | parse_sarif: total_issues=2
# INFO | save_analysis: streamdown con 2 issues
# INFO | Analisis CodeQL guardado en results/streamdown-codeql.json
# INFO | [23/25] Procesando repositorio miner/repos/styled-jsx
# INFO | Lenguaje detectado en styled-jsx: javascript
# INFO | Creando base de datos CodeQL para styled-jsx (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/styled-jsx_temp.sarif (214094 bytes)
# INFO | SARIF output length: 214094 bytes
# INFO | parse_sarif: recibiendo 214094 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 19 resultados en run[0]
# INFO | parse_sarif: total_issues=19
# INFO | save_analysis: styled-jsx con 19 issues
# INFO | Analisis CodeQL guardado en results/styled-jsx-codeql.json
# INFO | [24/25] Procesando repositorio miner/repos/swr
# INFO | Lenguaje detectado en swr: javascript
# INFO | Creando base de datos CodeQL para swr (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/swr_temp.sarif (369367 bytes)
# INFO | SARIF output length: 369367 bytes
# INFO | parse_sarif: recibiendo 369367 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 15 resultados en run[0]
# INFO | parse_sarif: total_issues=15
# INFO | save_analysis: swr con 15 issues
# INFO | Analisis CodeQL guardado en results/swr-codeql.json
# INFO | [25/25] Procesando repositorio miner/repos/vercel
# INFO | Lenguaje detectado en vercel: javascript
# INFO | Creando base de datos CodeQL para vercel (lenguaje: javascript)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/javascript-queries/2.3.8/codeql-suites/javascript-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/vercel_temp.sarif (9560421 bytes)
# INFO | SARIF output length: 9560421 bytes
# INFO | parse_sarif: recibiendo 9560421 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 646 resultados en run[0]
# INFO | parse_sarif: total_issues=646
# INFO | save_analysis: vercel con 646 issues
# INFO | Analisis CodeQL guardado en results/vercel-codeql.json
# INFO | Resumen final | total_repos=25 | repos_analizados=25 | archivos_generados=25 | omitidos=0 | errores=0
# INFO | Usando CodeQL CLI: /usr/local/bin/codeql
# INFO | === Diagnóstico del Entorno CodeQL ===
# INFO | ✓ CodeQL CLI: CodeQL command-line toolchain release 2.25.1.
# INFO | ✓ Node.js: v20.20.2
# INFO | ✓ npm: 10.8.2
# INFO | Verificando query packs...
# INFO | ✓ Query pack codeql/python-queries disponible
# INFO | ✓ Query pack codeql/javascript-queries disponible
# INFO | ✓ Query pack codeql/java-queries disponible
# INFO | ✓ Query pack codeql/actions-queries disponible
# INFO | === Fin Diagnóstico ===
#
# INFO | [1/25] Procesando repositorio miner/repos/ai
# INFO | Pipeline mode: analizando pipeline de ai...
# INFO | Creando base de datos CodeQL para ai (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/ai_temp.sarif (2026826 bytes)
# INFO | SARIF output length: 2026826 bytes
# INFO | parse_sarif: recibiendo 2026826 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 26 resultados en run[0]
# INFO | parse_sarif: total_issues=26
# INFO | save_analysis: ai con 26 issues
# INFO | Analisis CodeQL guardado en results/ai-pipeline.json
# INFO | [2/25] Procesando repositorio miner/repos/chatbot
# INFO | Pipeline mode: analizando pipeline de chatbot...
# INFO | Creando base de datos CodeQL para chatbot (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/chatbot_temp.sarif (224757 bytes)
# INFO | SARIF output length: 224757 bytes
# INFO | parse_sarif: recibiendo 224757 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 4 resultados en run[0]
# INFO | parse_sarif: total_issues=4
# INFO | save_analysis: chatbot con 4 issues
# INFO | Analisis CodeQL guardado en results/chatbot-pipeline.json
# INFO | [3/25] Procesando repositorio miner/repos/commerce
# INFO | Pipeline mode: analizando pipeline de commerce...
# INFO | Creando base de datos CodeQL para commerce (lenguaje: actions)...
# ERROR | [3/25] Error al procesar miner/repos/commerce: No fue posible crear la base de datos CodeQL para commerce: Initializing database at /tmp/codeql_analysis/commerce_db.
# Running build command: []
# Running command in /workspaces/Proyecto-Ciberseguridad/miner/repos/commerce: [/usr/local/codeql/actions/tools/autobuild.sh]
# Finalizing database at /tmp/codeql_analysis/commerce_db.
# CodeQL detected code written in JavaScript/TypeScript, but not any written in GitHub Actions. Confirm that there is some source code for GitHub Actions in the project. For more information, review our troubleshooting guide at https://gh.io/troubleshooting-code-scanning/no-source-code-seen-during-build.
# INFO | [4/25] Procesando repositorio miner/repos/examples
# INFO | Pipeline mode: analizando pipeline de examples...
# INFO | Creando base de datos CodeQL para examples (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/examples_temp.sarif (1160174 bytes)
# INFO | SARIF output length: 1160174 bytes
# INFO | parse_sarif: recibiendo 1160174 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 8 resultados en run[0]
# INFO | parse_sarif: total_issues=8
# INFO | save_analysis: examples con 8 issues
# INFO | Analisis CodeQL guardado en results/examples-pipeline.json
# INFO | [5/25] Procesando repositorio miner/repos/hazel
# INFO | Pipeline mode: analizando pipeline de hazel...
# INFO | Creando base de datos CodeQL para hazel (lenguaje: actions)...
# ERROR | [5/25] Error al procesar miner/repos/hazel: No fue posible crear la base de datos CodeQL para hazel: Initializing database at /tmp/codeql_analysis/hazel_db.
# Running build command: []
# Running command in /workspaces/Proyecto-Ciberseguridad/miner/repos/hazel: [/usr/local/codeql/actions/tools/autobuild.sh]
# Finalizing database at /tmp/codeql_analysis/hazel_db.
# CodeQL detected code written in GitHub Actions but could not process any of it. For more information, review our troubleshooting guide at https://gh.io/troubleshooting-code-scanning/no-source-code-seen-during-build.
# INFO | [6/25] Procesando repositorio miner/repos/hyper
# INFO | Pipeline mode: analizando pipeline de hyper...
# INFO | Creando base de datos CodeQL para hyper (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/hyper_temp.sarif (216665 bytes)
# INFO | SARIF output length: 216665 bytes
# INFO | parse_sarif: recibiendo 216665 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 15 resultados en run[0]
# INFO | parse_sarif: total_issues=15
# INFO | save_analysis: hyper con 15 issues
# INFO | Analisis CodeQL guardado en results/hyper-pipeline.json
# INFO | [7/25] Procesando repositorio miner/repos/kirimase
# INFO | Pipeline mode: analizando pipeline de kirimase...
# INFO | Creando base de datos CodeQL para kirimase (lenguaje: actions)...
# ERROR | [7/25] Error al procesar miner/repos/kirimase: No fue posible crear la base de datos CodeQL para kirimase: Initializing database at /tmp/codeql_analysis/kirimase_db.
# Running build command: []
# Running command in /workspaces/Proyecto-Ciberseguridad/miner/repos/kirimase: [/usr/local/codeql/actions/tools/autobuild.sh]
# Finalizing database at /tmp/codeql_analysis/kirimase_db.
# CodeQL detected code written in JavaScript/TypeScript, but not any written in GitHub Actions. Confirm that there is some source code for GitHub Actions in the project. For more information, review our troubleshooting guide at https://gh.io/troubleshooting-code-scanning/no-source-code-seen-during-build.
# INFO | [8/25] Procesando repositorio miner/repos/micro
# INFO | Pipeline mode: analizando pipeline de micro...
# INFO | Creando base de datos CodeQL para micro (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/micro_temp.sarif (173177 bytes)
# INFO | SARIF output length: 173177 bytes
# INFO | parse_sarif: recibiendo 173177 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 1 resultados en run[0]
# INFO | parse_sarif: total_issues=1
# INFO | save_analysis: micro con 1 issues
# INFO | Analisis CodeQL guardado en results/micro-pipeline.json
# INFO | [9/25] Procesando repositorio miner/repos/ms
# INFO | Pipeline mode: analizando pipeline de ms...
# INFO | Creando base de datos CodeQL para ms (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/ms_temp.sarif (171337 bytes)
# INFO | SARIF output length: 171337 bytes
# INFO | parse_sarif: recibiendo 171337 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 5 resultados en run[0]
# INFO | parse_sarif: total_issues=5
# INFO | save_analysis: ms con 5 issues
# INFO | Analisis CodeQL guardado en results/ms-pipeline.json
# INFO | [10/25] Procesando repositorio miner/repos/ncc
# INFO | Pipeline mode: analizando pipeline de ncc...
# INFO | Creando base de datos CodeQL para ncc (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/ncc_temp.sarif (236940 bytes)
# INFO | SARIF output length: 236940 bytes
# INFO | parse_sarif: recibiendo 236940 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 2 resultados en run[0]
# INFO | parse_sarif: total_issues=2
# INFO | save_analysis: ncc con 2 issues
# INFO | Analisis CodeQL guardado en results/ncc-pipeline.json
# INFO | [11/25] Procesando repositorio miner/repos/next-app-router-playground
# INFO | Pipeline mode: analizando pipeline de next-app-router-playground...
# INFO | Creando base de datos CodeQL para next-app-router-playground (lenguaje: actions)...
# ERROR | [11/25] Error al procesar miner/repos/next-app-router-playground: No fue posible crear la base de datos CodeQL para next-app-router-playground: Initializing database at /tmp/codeql_analysis/next-app-router-playground_db.
# Running build command: []
# Running command in /workspaces/Proyecto-Ciberseguridad/miner/repos/next-app-router-playground: [/usr/local/codeql/actions/tools/autobuild.sh]
# Finalizing database at /tmp/codeql_analysis/next-app-router-playground_db.
# CodeQL detected code written in JavaScript/TypeScript, but not any written in GitHub Actions. Confirm that there is some source code for GitHub Actions in the project. For more information, review our troubleshooting guide at https://gh.io/troubleshooting-code-scanning/no-source-code-seen-during-build.
# INFO | [12/25] Procesando repositorio miner/repos/next-forge
# INFO | Pipeline mode: analizando pipeline de next-forge...
# INFO | Creando base de datos CodeQL para next-forge (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/next-forge_temp.sarif (314035 bytes)
# INFO | SARIF output length: 314035 bytes
# INFO | parse_sarif: recibiendo 314035 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 1 resultados en run[0]
# INFO | parse_sarif: total_issues=1
# INFO | save_analysis: next-forge con 1 issues
# INFO | Analisis CodeQL guardado en results/next-forge-pipeline.json
# INFO | [13/25] Procesando repositorio miner/repos/next-learn
# INFO | Pipeline mode: analizando pipeline de next-learn...
# INFO | Creando base de datos CodeQL para next-learn (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/next-learn_temp.sarif (220153 bytes)
# INFO | SARIF output length: 220153 bytes
# INFO | parse_sarif: recibiendo 220153 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 4 resultados en run[0]
# INFO | parse_sarif: total_issues=4
# INFO | save_analysis: next-learn con 4 issues
# INFO | Analisis CodeQL guardado en results/next-learn-pipeline.json
# INFO | [14/25] Procesando repositorio miner/repos/next.js
# INFO | Pipeline mode: analizando pipeline de next.js...
# INFO | Creando base de datos CodeQL para next.js (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/next.js_temp.sarif (9347213 bytes)
# INFO | SARIF output length: 9347213 bytes
# INFO | parse_sarif: recibiendo 9347213 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 94 resultados en run[0]
# INFO | parse_sarif: total_issues=94
# INFO | save_analysis: next.js con 94 issues
# INFO | Analisis CodeQL guardado en results/next.js-pipeline.json
# INFO | [15/25] Procesando repositorio miner/repos/nextjs-subscription-payments
# INFO | Pipeline mode: analizando pipeline de nextjs-subscription-payments...
# INFO | Creando base de datos CodeQL para nextjs-subscription-payments (lenguaje: actions)...
# ERROR | [15/25] Error al procesar miner/repos/nextjs-subscription-payments: No fue posible crear la base de datos CodeQL para nextjs-subscription-payments: Initializing database at /tmp/codeql_analysis/nextjs-subscription-payments_db.
# Running build command: []
# Running command in /workspaces/Proyecto-Ciberseguridad/miner/repos/nextjs-subscription-payments: [/usr/local/codeql/actions/tools/autobuild.sh]
# Finalizing database at /tmp/codeql_analysis/nextjs-subscription-payments_db.
# CodeQL detected code written in JavaScript/TypeScript, but not any written in GitHub Actions. Confirm that there is some source code for GitHub Actions in the project. For more information, review our troubleshooting guide at https://gh.io/troubleshooting-code-scanning/no-source-code-seen-during-build.
# INFO | [16/25] Procesando repositorio miner/repos/og-image
# INFO | Pipeline mode: analizando pipeline de og-image...
# INFO | Creando base de datos CodeQL para og-image (lenguaje: actions)...
# ERROR | [16/25] Error al procesar miner/repos/og-image: No fue posible crear la base de datos CodeQL para og-image: Initializing database at /tmp/codeql_analysis/og-image_db.
# Running build command: []
# Running command in /workspaces/Proyecto-Ciberseguridad/miner/repos/og-image: [/usr/local/codeql/actions/tools/autobuild.sh]
# Finalizing database at /tmp/codeql_analysis/og-image_db.
# CodeQL detected code written in JavaScript/TypeScript, but not any written in GitHub Actions. Confirm that there is some source code for GitHub Actions in the project. For more information, review our troubleshooting guide at https://gh.io/troubleshooting-code-scanning/no-source-code-seen-during-build.
# INFO | [17/25] Procesando repositorio miner/repos/pkg
# INFO | Pipeline mode: analizando pipeline de pkg...
# INFO | Creando base de datos CodeQL para pkg (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/pkg_temp.sarif (565818 bytes)
# INFO | SARIF output length: 565818 bytes
# INFO | parse_sarif: recibiendo 565818 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 2 resultados en run[0]
# INFO | parse_sarif: total_issues=2
# INFO | save_analysis: pkg con 2 issues
# INFO | Analisis CodeQL guardado en results/pkg-pipeline.json
# INFO | [18/25] Procesando repositorio miner/repos/platforms
# INFO | Pipeline mode: analizando pipeline de platforms...
# INFO | Creando base de datos CodeQL para platforms (lenguaje: actions)...
# ERROR | [18/25] Error al procesar miner/repos/platforms: No fue posible crear la base de datos CodeQL para platforms: Initializing database at /tmp/codeql_analysis/platforms_db.
# Running build command: []
# Running command in /workspaces/Proyecto-Ciberseguridad/miner/repos/platforms: [/usr/local/codeql/actions/tools/autobuild.sh]
# Finalizing database at /tmp/codeql_analysis/platforms_db.
# CodeQL detected code written in JavaScript/TypeScript, but not any written in GitHub Actions. Confirm that there is some source code for GitHub Actions in the project. For more information, review our troubleshooting guide at https://gh.io/troubleshooting-code-scanning/no-source-code-seen-during-build.
# INFO | [19/25] Procesando repositorio miner/repos/release
# INFO | Pipeline mode: analizando pipeline de release...
# INFO | Creando base de datos CodeQL para release (lenguaje: actions)...
# ERROR | [19/25] Error al procesar miner/repos/release: No fue posible crear la base de datos CodeQL para release: Initializing database at /tmp/codeql_analysis/release_db.
# Running build command: []
# Running command in /workspaces/Proyecto-Ciberseguridad/miner/repos/release: [/usr/local/codeql/actions/tools/autobuild.sh]
# Finalizing database at /tmp/codeql_analysis/release_db.
# CodeQL detected code written in GitHub Actions but could not process any of it. For more information, review our troubleshooting guide at https://gh.io/troubleshooting-code-scanning/no-source-code-seen-during-build.
# INFO | [20/25] Procesando repositorio miner/repos/satori
# INFO | Pipeline mode: analizando pipeline de satori...
# INFO | Creando base de datos CodeQL para satori (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/satori_temp.sarif (207320 bytes)
# INFO | SARIF output length: 207320 bytes
# INFO | parse_sarif: recibiendo 207320 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 2 resultados en run[0]
# INFO | parse_sarif: total_issues=2
# INFO | save_analysis: satori con 2 issues
# INFO | Analisis CodeQL guardado en results/satori-pipeline.json
# INFO | [21/25] Procesando repositorio miner/repos/serve
# INFO | Pipeline mode: analizando pipeline de serve...
# INFO | Creando base de datos CodeQL para serve (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/serve_temp.sarif (176141 bytes)
# INFO | SARIF output length: 176141 bytes
# INFO | parse_sarif: recibiendo 176141 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 9 resultados en run[0]
# INFO | parse_sarif: total_issues=9
# INFO | save_analysis: serve con 9 issues
# INFO | Analisis CodeQL guardado en results/serve-pipeline.json
# INFO | [22/25] Procesando repositorio miner/repos/streamdown
# INFO | Pipeline mode: analizando pipeline de streamdown...
# INFO | Creando base de datos CodeQL para streamdown (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/streamdown_temp.sarif (295752 bytes)
# INFO | SARIF output length: 295752 bytes
# INFO | parse_sarif: recibiendo 295752 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 3 resultados en run[0]
# INFO | parse_sarif: total_issues=3
# INFO | save_analysis: streamdown con 3 issues
# INFO | Analisis CodeQL guardado en results/streamdown-pipeline.json
# INFO | [23/25] Procesando repositorio miner/repos/styled-jsx
# INFO | Pipeline mode: analizando pipeline de styled-jsx...
# INFO | Creando base de datos CodeQL para styled-jsx (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/styled-jsx_temp.sarif (195294 bytes)
# INFO | SARIF output length: 195294 bytes
# INFO | parse_sarif: recibiendo 195294 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 3 resultados en run[0]
# INFO | parse_sarif: total_issues=3
# INFO | save_analysis: styled-jsx con 3 issues
# INFO | Analisis CodeQL guardado en results/styled-jsx-pipeline.json
# INFO | [24/25] Procesando repositorio miner/repos/swr
# INFO | Pipeline mode: analizando pipeline de swr...
# INFO | Creando base de datos CodeQL para swr (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/swr_temp.sarif (267533 bytes)
# INFO | SARIF output length: 267533 bytes
# INFO | parse_sarif: recibiendo 267533 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 5 resultados en run[0]
# INFO | parse_sarif: total_issues=5
# INFO | save_analysis: swr con 5 issues
# INFO | Analisis CodeQL guardado en results/swr-pipeline.json
# INFO | [25/25] Procesando repositorio miner/repos/vercel
# INFO | Pipeline mode: analizando pipeline de vercel...
# INFO | Creando base de datos CodeQL para vercel (lenguaje: actions)...
# INFO | Usando suite compilada: /home/vscode/.codeql/packages/codeql/actions-queries/0.6.26/codeql-suites/actions-security-and-quality.qls
# INFO | SARIF guardado en: /workspaces/Proyecto-Ciberseguridad/results/vercel_temp.sarif (2734298 bytes)
# INFO | SARIF output length: 2734298 bytes
# INFO | parse_sarif: recibiendo 2734298 bytes
# INFO | parse_sarif: 1 runs encontrados
# INFO | parse_sarif: 22 resultados en run[0]
# INFO | parse_sarif: total_issues=22
# INFO | save_analysis: vercel con 22 issues
# INFO | Analisis CodeQL guardado en results/vercel-pipeline.json
# INFO | Resumen final | total_repos=25 | repos_analizados=17 | archivos_generados=17 | omitidos=0 | errores=8

# %% [markdown]
# ## Paso 4: Analizar vulnerabilidades de dependencias con Grype

# %%
from generate_grype import GrypeAnalyzer

grype_analyzer = GrypeAnalyzer(str(RUTA_REPOS), str(RUTA_RESULTADOS))
grype_analyzer.run()
# Out:
# INFO | === Grype Environment Diagnostics ===
# INFO | Grype CLI: Application:         grype
# Version:             0.112.0
# BuildDate:           2026-05-01T18:57:12Z
# GitCommit:           244f2a10a5668078fcf771454bbd832b3a5b9e8a
# GitDescription:      v0.112.0
# Platform:            linux/amd64
# GoVersion:           go1.26.2
# Compiler:            gc
# Syft Version:        v1.44.0
# Supported DB Schema: 6
# INFO | Grype DB status: Path:      /home/vscode/.cache/grype/db/6/vulnerability.db
# Schema:    v6.1.4
# Built:     2026-05-07T07:17:40Z
# From:      https://grype.anchore.io/databases/v6/vulnerability-db_v6.1.4_2026-05-07T00:43:40Z_1778138260.tar.zst?checksum=sha256%3Ae5488827ffe1d846bcc1423b434741b4240bdbacef1545ee000901f6b0c50793
# Status:    valid
# INFO | === Environment Check Complete ===
#
# INFO | [1/25] Scanning miner/repos/ai with Grype...
# INFO | Manifests found in ai: package.json, requirements.txt
# INFO | Running Grype on ai...
# INFO | Parsing Grype output...
# INFO | Found 289 matches in Grype output
# INFO | Parsed 289 vulnerabilities total
# INFO | Raw Grype output saved to results/ai-grype-raw.json
# INFO | Normalized analysis saved to results/ai-grype.json
# INFO | [2/25] Scanning miner/repos/chatbot with Grype...
# INFO | Manifests found in chatbot: package.json
# INFO | Running Grype on chatbot...
# INFO | Parsing Grype output...
# INFO | Found 33 matches in Grype output
# INFO | Parsed 33 vulnerabilities total
# INFO | Raw Grype output saved to results/chatbot-grype-raw.json
# INFO | Normalized analysis saved to results/chatbot-grype.json
# INFO | [3/25] Scanning miner/repos/commerce with Grype...
# INFO | Manifests found in commerce: package.json
# INFO | Running Grype on commerce...
# INFO | Parsing Grype output...
# INFO | Found 5 matches in Grype output
# INFO | Parsed 5 vulnerabilities total
# INFO | Raw Grype output saved to results/commerce-grype-raw.json
# INFO | Normalized analysis saved to results/commerce-grype.json
# INFO | [4/25] Scanning miner/repos/examples with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# amqp==5.3.1
#     # via kombu
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   starlette
#     #   vercel
#     #   vercel-workers
# billiard==4.2.4
#     # via celery
# cbor2==6.0.1
#     # via vercel
# celery==5.6.3
#     # via celery-vercel (pyproject.toml)
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via
#     #   celery
#     #   click-didyoumean
#     #   click-plugins
#     #   click-repl
# click-didyoumean==0.3.1
#     # via celery
# click-plugins==1.1.1.2
#     # via celery
# click-repl==0.3.0
#     # via celery
# fastapi==0.136.1
#     # via celery-vercel (pyproject.toml)
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# jinja2==3.1.6
#     # via celery-vercel (pyproject.toml)
# kombu==5.6.2
#     # via celery
# markupsafe==3.0.3
#     # via jinja2
# packaging==26.2
#     # via kombu
# prompt-toolkit==3.0.52
#     # via click-repl
# pydantic==2.13.4
#     # via
#     #   fastapi
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dateutil==2.9.0.post0
#     # via celery
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# redis==7.4.0
#     # via celery-vercel (pyproject.toml)
# six==1.17.0
#     # via python-dateutil
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# tzdata==2026.2
#     # via kombu
# tzlocal==5.3.1
#     # via celery
# vercel==0.5.8
#     # via
#     #   celery-vercel (pyproject.toml)
#     #   vercel-workers
# vercel-workers==0.0.22
#     # via vercel
# vine==5.1.0
#     # via
#     #   amqp
#     #   celery
#     #   kombu
# wcwidth==0.7.0
#     # via prompt-toolkit
# websockets==16.0
#     # via vercel
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via fastapi-example (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# asgiref==3.11.1
#     # via django
# django==6.0.5
#     # via django-notes (pyproject.toml)
# psycopg==3.3.4
#     # via django-notes (pyproject.toml)
# psycopg-binary==3.3.4
#     # via psycopg
# sqlparse==0.5.5
#     # via django
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# anyio==4.13.0
#     # via starlette
# idna==3.13
#     # via anyio
# starlette==1.0.0
#     # via vercel-starlette-starter (pyproject.toml)
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# asgiref==3.11.1
#     # via django
# django==6.0.5
#     # via
#     #   django-rest-framework (pyproject.toml)
#     #   djangorestframework
# djangorestframework==3.17.1
#     # via django-rest-framework (pyproject.toml)
# gunicorn==26.0.0
#     # via django-rest-framework (pyproject.toml)
# packaging==26.2
#     # via gunicorn
# sqlparse==0.5.5
#     # via django
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# asgiref==3.11.1
#     # via django
# django==6.0.5
#     # via django-vercel (pyproject.toml)
# sqlparse==0.5.5
#     # via django
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# blinker==1.9.0
#     # via flask
# click==8.3.3
#     # via flask
# flask==3.1.3
#     # via vercel-flask-starter (pyproject.toml)
# gunicorn==23.0.0
#     # via vercel-flask-starter (pyproject.toml)
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# packaging==26.2
#     # via gunicorn
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# aiohappyeyeballs==2.6.1
#     # via aiohttp
# aiohttp==3.13.5
#     # via litellm
# aiosignal==1.4.0
#     # via aiohttp
# annotated-doc==0.0.4
#     # via typer
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   mcp
#     #   openai
#     #   sse-starlette
#     #   starlette
#     #   vercel
#     #   vercel-workers
# attrs==26.1.0
#     # via
#     #   aiohttp
#     #   jsonschema
#     #   referencing
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
# charset-normalizer==3.4.7
#     # via requests
# click==8.3.3
#     # via
#     #   litellm
#     #   typer
#     #   uvicorn
# distro==1.9.0
#     # via openai
# fastapi==0.117.1
#     # via nfactorial-code-agent-backend (pyproject.toml)
# fastuuid==0.14.0
#     # via litellm
# filelock==3.29.0
#     # via huggingface-hub
# frozenlist==1.8.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2026.4.0
#     # via huggingface-hub
# griffelib==2.0.2
#     # via openai-agents
# h11==0.16.0
#     # via
#     #   httpcore
#     #   uvicorn
# hf-xet==1.5.0
#     # via huggingface-hub
# httpcore==1.0.9
#     # via httpx
# httpx==0.27.2
#     # via
#     #   huggingface-hub
#     #   litellm
#     #   mcp
#     #   nfactorial-code-agent-backend (pyproject.toml)
#     #   openai
#     #   vercel
#     #   vercel-workers
# httpx-sse==0.4.0
#     # via
#     #   mcp
#     #   nfactorial-code-agent-backend (pyproject.toml)
# huggingface-hub==1.14.0
#     # via tokenizers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
#     #   requests
#     #   yarl
# importlib-metadata==9.0.0
#     # via litellm
# jinja2==3.1.6
#     # via litellm
# jiter==0.14.0
#     # via openai
# jsonschema==4.26.0
#     # via
#     #   litellm
#     #   mcp
# jsonschema-specifications==2025.9.1
#     # via jsonschema
# litellm==1.83.0
#     # via openai-agents
# markdown-it-py==4.2.0
#     # via rich
# markupsafe==3.0.3
#     # via jinja2
# mcp==1.19.0
#     # via openai-agents
# mdurl==0.1.2
#     # via markdown-it-py
# multidict==6.7.1
#     # via
#     #   aiohttp
#     #   yarl
# openai==2.36.0
#     # via
#     #   litellm
#     #   openai-agents
# openai-agents==0.16.1
#     # via nfactorial-code-agent-backend (pyproject.toml)
# packaging==26.2
#     # via huggingface-hub
# propcache==0.4.1
#     # via
#     #   aiohttp
#     #   yarl
# pydantic==2.13.4
#     # via
#     #   fastapi
#     #   litellm
#     #   mcp
#     #   nfactorial-code-agent-backend (pyproject.toml)
#     #   openai
#     #   openai-agents
#     #   pydantic-settings
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# pydantic-settings==2.14.0
#     # via mcp
# pygments==2.20.0
#     # via rich
# pyjwt==2.9.0
#     # via nfactorial-code-agent-backend (pyproject.toml)
# python-dotenv==1.0.0
#     # via
#     #   litellm
#     #   nfactorial-code-agent-backend (pyproject.toml)
#     #   pydantic-settings
#     #   vercel
#     #   vercel-workers
# python-multipart==0.0.27
#     # via mcp
# pyyaml==6.0.3
#     # via huggingface-hub
# referencing==0.37.0
#     # via
#     #   jsonschema
#     #   jsonschema-specifications
# regex==2026.4.4
#     # via tiktoken
# requests==2.33.1
#     # via
#     #   openai-agents
#     #   tiktoken
# rich==15.0.0
#     # via typer
# rpds-py==0.30.0
#     # via
#     #   jsonschema
#     #   referencing
# ruff==0.15.12
#     # via nfactorial-code-agent-backend (pyproject.toml)
# shellingham==1.5.4
#     # via typer
# sniffio==1.3.1
#     # via
#     #   httpx
#     #   openai
# sse-starlette==3.0.3
#     # via mcp
# starlette==0.48.0
#     # via
#     #   fastapi
#     #   mcp
# tiktoken==0.12.0
#     # via litellm
# tokenizers==0.23.1
#     # via litellm
# tqdm==4.67.3
#     # via
#     #   huggingface-hub
#     #   openai
# typer==0.25.1
#     # via huggingface-hub
# types-requests==2.33.0.20260503
#     # via openai-agents
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   huggingface-hub
#     #   openai
#     #   openai-agents
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   pydantic
#     #   pydantic-settings
# urllib3==2.7.0
#     # via
#     #   requests
#     #   types-requests
# uvicorn==0.34.2
#     # via
#     #   mcp
#     #   nfactorial-code-agent-backend (pyproject.toml)
# vercel==0.5.8
#     # via
#     #   nfactorial-code-agent-backend (pyproject.toml)
#     #   vercel-workers
# vercel-workers==0.0.22
#     # via vercel
# websockets==16.0
#     # via
#     #   openai-agents
#     #   vercel
# yarl==1.23.0
#     # via aiohttp
# zipp==3.23.1
#     # via importlib-metadata
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# blinker==1.9.0
#     # via flask
# click==8.3.3
#     # via flask
# flask==3.1.3
#     # via vercel-flask-starter (pyproject.toml)
# gunicorn==23.0.0
#     # via vercel-flask-starter (pyproject.toml)
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# packaging==26.2
#     # via gunicorn
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# aiohappyeyeballs==2.6.1
#     # via aiohttp
# aiohttp==3.13.5
#     # via litellm
# aiosignal==1.4.0
#     # via aiohttp
# annotated-doc==0.0.4
#     # via
#     #   fastapi
#     #   typer
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   mcp
#     #   openai
#     #   sse-starlette
#     #   starlette
# apscheduler==3.11.2
#     # via litellm
# attrs==26.1.0
#     # via
#     #   aiohttp
#     #   jsonschema
#     #   referencing
# azure-core==1.40.0
#     # via
#     #   azure-identity
#     #   azure-storage-blob
# azure-identity==1.25.3
#     # via litellm
# azure-storage-blob==12.28.0
#     # via litellm
# backoff==2.2.1
#     # via litellm
# boto3==1.42.80
#     # via litellm
# botocore==1.42.97
#     # via
#     #   boto3
#     #   s3transfer
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
#     #   requests
# cffi==2.0.0
#     # via
#     #   cryptography
#     #   pynacl
#     #   pyroscope-io
#     #   soundfile
# charset-normalizer==3.4.7
#     # via requests
# click==8.1.8
#     # via
#     #   litellm
#     #   rq
#     #   typer
#     #   uvicorn
# croniter==6.2.2
#     # via rq
# cryptography==43.0.3
#     # via
#     #   azure-identity
#     #   azure-storage-blob
#     #   litellm
#     #   msal
#     #   pyjwt
# distro==1.9.0
#     # via openai
# dnspython==2.8.0
#     # via email-validator
# email-validator==2.3.0
#     # via pydantic
# fastapi==0.124.4
#     # via
#     #   fastapi-sso
#     #   litellm
#     #   litellm-gateway (pyproject.toml)
# fastapi-sso==0.16.0
#     # via litellm
# fastuuid==0.14.0
#     # via litellm
# filelock==3.29.0
#     # via huggingface-hub
# frozenlist==1.8.0
#     # via
#     #   aiohttp
#     #   aiosignal
# fsspec==2026.4.0
#     # via huggingface-hub
# gunicorn==23.0.0
#     # via litellm
# h11==0.16.0
#     # via
#     #   httpcore
#     #   uvicorn
# hf-xet==1.5.0
#     # via huggingface-hub
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   fastapi-sso
#     #   huggingface-hub
#     #   litellm
#     #   mcp
#     #   openai
# httpx-sse==0.4.3
#     # via mcp
# huggingface-hub==1.14.0
#     # via tokenizers
# idna==3.13
#     # via
#     #   anyio
#     #   email-validator
#     #   httpx
#     #   requests
#     #   yarl
# importlib-metadata==8.5.0
#     # via litellm
# isodate==0.7.2
#     # via azure-storage-blob
# jinja2==3.1.6
#     # via litellm
# jiter==0.14.0
#     # via openai
# jmespath==1.1.0
#     # via
#     #   boto3
#     #   botocore
# jsonschema==4.23.0
#     # via
#     #   litellm
#     #   mcp
# jsonschema-specifications==2025.9.1
#     # via jsonschema
# litellm==1.83.7
#     # via litellm-gateway (pyproject.toml)
# litellm-enterprise==0.1.37
#     # via litellm
# litellm-proxy-extras==0.4.65
#     # via litellm
# markdown-it-py==4.2.0
#     # via rich
# markupsafe==3.0.3
#     # via jinja2
# mcp==1.26.0
#     # via litellm
# mdurl==0.1.2
#     # via markdown-it-py
# msal==1.36.0
#     # via
#     #   azure-identity
#     #   msal-extensions
# msal-extensions==1.3.1
#     # via azure-identity
# multidict==6.7.1
#     # via
#     #   aiohttp
#     #   yarl
# oauthlib==3.3.1
#     # via fastapi-sso
# openai==2.30.0
#     # via litellm
# orjson==3.10.15
#     # via litellm
# packaging==26.2
#     # via
#     #   gunicorn
#     #   huggingface-hub
# polars==1.39.3
#     # via litellm
# polars-runtime-32==1.39.3
#     # via polars
# propcache==0.4.1
#     # via
#     #   aiohttp
#     #   yarl
# pycparser==3.0
#     # via cffi
# pydantic==2.12.5
#     # via
#     #   fastapi
#     #   fastapi-sso
#     #   litellm
#     #   mcp
#     #   openai
#     #   pydantic-settings
# pydantic-core==2.41.5
#     # via pydantic
# pydantic-settings==2.14.0
#     # via mcp
# pygments==2.20.0
#     # via rich
# pyjwt==2.12.1
#     # via
#     #   litellm
#     #   mcp
#     #   msal
# pynacl==1.6.2
#     # via litellm
# pyroscope-io==0.8.16
#     # via litellm
# python-dateutil==2.9.0.post0
#     # via
#     #   botocore
#     #   croniter
# python-dotenv==1.0.1
#     # via
#     #   litellm
#     #   pydantic-settings
# python-multipart==0.0.20
#     # via
#     #   litellm
#     #   mcp
# pyyaml==6.0.3
#     # via
#     #   huggingface-hub
#     #   litellm
# redis==7.4.0
#     # via rq
# referencing==0.37.0
#     # via
#     #   jsonschema
#     #   jsonschema-specifications
# regex==2026.4.4
#     # via tiktoken
# requests==2.33.1
#     # via
#     #   azure-core
#     #   msal
#     #   tiktoken
# rich==13.9.4
#     # via
#     #   litellm
#     #   typer
# rpds-py==0.30.0
#     # via
#     #   jsonschema
#     #   referencing
# rq==2.7.0
#     # via litellm
# s3transfer==0.16.1
#     # via boto3
# shellingham==1.5.4
#     # via typer
# six==1.17.0
#     # via python-dateutil
# sniffio==1.3.1
#     # via openai
# soundfile==0.12.1
#     # via litellm
# sse-starlette==3.4.2
#     # via mcp
# starlette==0.50.0
#     # via
#     #   fastapi
#     #   mcp
#     #   sse-starlette
# tiktoken==0.12.0
#     # via litellm
# tokenizers==0.22.2
#     # via litellm
# tqdm==4.67.3
#     # via
#     #   huggingface-hub
#     #   openai
# typer==0.23.1
#     # via huggingface-hub
# typing-extensions==4.15.0
#     # via
#     #   azure-core
#     #   azure-identity
#     #   azure-storage-blob
#     #   fastapi
#     #   huggingface-hub
#     #   mcp
#     #   openai
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   mcp
#     #   pydantic
#     #   pydantic-settings
# tzlocal==5.3.1
#     # via apscheduler
# urllib3==2.7.0
#     # via
#     #   botocore
#     #   requests
# uvicorn==0.33.0
#     # via
#     #   litellm
#     #   mcp
# uvloop==0.21.0
#     # via litellm
# websockets==15.0.1
#     # via litellm
# yarl==1.23.0
#     # via aiohttp
# zipp==3.23.1
#     # via importlib-metadata
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# click==8.3.3
#     # via uvicorn
# fastapi==0.136.1
#     # via next-fastapi-monorepo-backend (pyproject.toml)
# h11==0.16.0
#     # via uvicorn
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# uvicorn==0.46.0
#     # via next-fastapi-monorepo-backend (pyproject.toml)
# INFO | Manifests found in examples: Cargo.lock, Cargo.toml, Gemfile, Gemfile.lock, go.mod, go.sum, package-lock.json, package.json, requirements.txt
# INFO | Running Grype on examples...
# INFO | Parsing Grype output...
# INFO | Found 5324 matches in Grype output
# INFO | Parsed 5324 vulnerabilities total
# INFO | Raw Grype output saved to results/examples-grype-raw.json
# INFO | Normalized analysis saved to results/examples-grype.json
# INFO | [5/25] Scanning miner/repos/hazel with Grype...
# INFO | Manifests found in hazel: package.json, yarn.lock
# INFO | Running Grype on hazel...
# INFO | Parsing Grype output...
# INFO | Found 123 matches in Grype output
# INFO | Parsed 123 vulnerabilities total
# INFO | Raw Grype output saved to results/hazel-grype-raw.json
# INFO | Normalized analysis saved to results/hazel-grype.json
# INFO | [6/25] Scanning miner/repos/hyper with Grype...
# INFO | Manifests found in hyper: package.json, yarn.lock
# INFO | Running Grype on hyper...
# INFO | Parsing Grype output...
# INFO | Found 44 matches in Grype output
# INFO | Parsed 44 vulnerabilities total
# INFO | Raw Grype output saved to results/hyper-grype-raw.json
# INFO | Normalized analysis saved to results/hyper-grype.json
# INFO | [7/25] Scanning miner/repos/kirimase with Grype...
# INFO | Manifests found in kirimase: package.json
# INFO | Running Grype on kirimase...
# INFO | Parsing Grype output...
# INFO | Found 2 matches in Grype output
# INFO | Parsed 2 vulnerabilities total
# INFO | Raw Grype output saved to results/kirimase-grype-raw.json
# INFO | Normalized analysis saved to results/kirimase-grype.json
# INFO | [8/25] Scanning miner/repos/micro with Grype...
# INFO | Manifests found in micro: package.json, yarn.lock
# INFO | Running Grype on micro...
# INFO | Parsing Grype output...
# INFO | Found 22 matches in Grype output
# INFO | Parsed 22 vulnerabilities total
# INFO | Raw Grype output saved to results/micro-grype-raw.json
# INFO | Normalized analysis saved to results/micro-grype.json
# INFO | [9/25] Scanning miner/repos/ms with Grype...
# INFO | Manifests found in ms: package.json
# INFO | Running Grype on ms...
# INFO | Parsing Grype output...
# INFO | Found 21 matches in Grype output
# INFO | Parsed 21 vulnerabilities total
# INFO | Raw Grype output saved to results/ms-grype-raw.json
# INFO | Normalized analysis saved to results/ms-grype.json
# INFO | [10/25] Scanning miner/repos/ncc with Grype...
# INFO | Manifests found in ncc: package.json, yarn.lock
# INFO | Running Grype on ncc...
# INFO | Parsing Grype output...
# INFO | Found 3 matches in Grype output
# INFO | Parsed 3 vulnerabilities total
# INFO | Raw Grype output saved to results/ncc-grype-raw.json
# INFO | Normalized analysis saved to results/ncc-grype.json
# INFO | [11/25] Scanning miner/repos/next-app-router-playground with Grype...
# INFO | Manifests found in next-app-router-playground: package.json
# INFO | Running Grype on next-app-router-playground...
# INFO | Parsing Grype output...
# INFO | Found 6 matches in Grype output
# INFO | Parsed 6 vulnerabilities total
# INFO | Raw Grype output saved to results/next-app-router-playground-grype-raw.json
# INFO | Normalized analysis saved to results/next-app-router-playground-grype.json
# INFO | [12/25] Scanning miner/repos/next-forge with Grype...
# INFO | Manifests found in next-forge: package.json
# INFO | Running Grype on next-forge...
# INFO | Parsing Grype output...
# INFO | Found 0 matches in Grype output
# INFO | Parsed 0 vulnerabilities total
# INFO | Raw Grype output saved to results/next-forge-grype-raw.json
# INFO | Normalized analysis saved to results/next-forge-grype.json
# INFO | [13/25] Scanning miner/repos/next-learn with Grype...
# INFO | Manifests found in next-learn: package.json
# INFO | Running Grype on next-learn...
# INFO | Parsing Grype output...
# INFO | Found 92 matches in Grype output
# INFO | Parsed 92 vulnerabilities total
# INFO | Raw Grype output saved to results/next-learn-grype-raw.json
# INFO | Normalized analysis saved to results/next-learn-grype.json
# INFO | [14/25] Scanning miner/repos/next.js with Grype...
# INFO | Manifests found in next.js: Cargo.lock, Cargo.toml, package-lock.json, package.json
# INFO | Running Grype on next.js...
# INFO | Parsing Grype output...
# INFO | Found 747 matches in Grype output
# INFO | Parsed 747 vulnerabilities total
# INFO | Raw Grype output saved to results/next.js-grype-raw.json
# INFO | Normalized analysis saved to results/next.js-grype.json
# INFO | [15/25] Scanning miner/repos/nextjs-subscription-payments with Grype...
# INFO | Manifests found in nextjs-subscription-payments: package.json
# INFO | Running Grype on nextjs-subscription-payments...
# INFO | Parsing Grype output...
# INFO | Found 39 matches in Grype output
# INFO | Parsed 39 vulnerabilities total
# INFO | Raw Grype output saved to results/nextjs-subscription-payments-grype-raw.json
# INFO | Normalized analysis saved to results/nextjs-subscription-payments-grype.json
# INFO | [16/25] Scanning miner/repos/og-image with Grype...
# INFO | Manifests found in og-image: package.json, yarn.lock
# INFO | Running Grype on og-image...
# INFO | Parsing Grype output...
# INFO | Found 9 matches in Grype output
# INFO | Parsed 9 vulnerabilities total
# INFO | Raw Grype output saved to results/og-image-grype-raw.json
# INFO | Normalized analysis saved to results/og-image-grype.json
# INFO | [17/25] Scanning miner/repos/pkg with Grype...
# INFO | Manifests found in pkg: package.json, yarn.lock
# INFO | Running Grype on pkg...
# INFO | Parsing Grype output...
# INFO | Found 8 matches in Grype output
# INFO | Parsed 8 vulnerabilities total
# INFO | Raw Grype output saved to results/pkg-grype-raw.json
# INFO | Normalized analysis saved to results/pkg-grype.json
# INFO | [18/25] Scanning miner/repos/platforms with Grype...
# INFO | Manifests found in platforms: package.json
# INFO | Running Grype on platforms...
# INFO | Parsing Grype output...
# INFO | Found 15 matches in Grype output
# INFO | Parsed 15 vulnerabilities total
# INFO | Raw Grype output saved to results/platforms-grype-raw.json
# INFO | Normalized analysis saved to results/platforms-grype.json
# INFO | [19/25] Scanning miner/repos/release with Grype...
# INFO | Manifests found in release: package.json, yarn.lock
# INFO | Running Grype on release...
# INFO | Parsing Grype output...
# INFO | Found 18 matches in Grype output
# INFO | Parsed 18 vulnerabilities total
# INFO | Raw Grype output saved to results/release-grype-raw.json
# INFO | Normalized analysis saved to results/release-grype.json
# INFO | [20/25] Scanning miner/repos/satori with Grype...
# INFO | Manifests found in satori: package.json
# INFO | Running Grype on satori...
# INFO | Parsing Grype output...
# INFO | Found 18 matches in Grype output
# INFO | Parsed 18 vulnerabilities total
# INFO | Raw Grype output saved to results/satori-grype-raw.json
# INFO | Normalized analysis saved to results/satori-grype.json
# INFO | [21/25] Scanning miner/repos/serve with Grype...
# INFO | Manifests found in serve: package.json
# INFO | Running Grype on serve...
# INFO | Parsing Grype output...
# INFO | Found 45 matches in Grype output
# INFO | Parsed 45 vulnerabilities total
# INFO | Raw Grype output saved to results/serve-grype-raw.json
# INFO | Normalized analysis saved to results/serve-grype.json
# INFO | [22/25] Scanning miner/repos/streamdown with Grype...
# INFO | Manifests found in streamdown: package.json
# INFO | Running Grype on streamdown...
# INFO | Parsing Grype output...
# INFO | Found 32 matches in Grype output
# INFO | Parsed 32 vulnerabilities total
# INFO | Raw Grype output saved to results/streamdown-grype-raw.json
# INFO | Normalized analysis saved to results/streamdown-grype.json
# INFO | [23/25] Scanning miner/repos/styled-jsx with Grype...
# INFO | Manifests found in styled-jsx: package.json, yarn.lock
# INFO | Running Grype on styled-jsx...
# INFO | Parsing Grype output...
# INFO | Found 0 matches in Grype output
# INFO | Parsed 0 vulnerabilities total
# INFO | Raw Grype output saved to results/styled-jsx-grype-raw.json
# INFO | Normalized analysis saved to results/styled-jsx-grype.json
# INFO | [24/25] Scanning miner/repos/swr with Grype...
# INFO | Manifests found in swr: package.json
# INFO | Running Grype on swr...
# INFO | Parsing Grype output...
# INFO | Found 32 matches in Grype output
# INFO | Parsed 32 vulnerabilities total
# INFO | Raw Grype output saved to results/swr-grype-raw.json
# INFO | Normalized analysis saved to results/swr-grype.json
# INFO | [25/25] Scanning miner/repos/vercel with Grype...
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# Backend subprocess exited when trying to invoke get_requires_for_build_wheel
# Failed to parse /workspaces/Proyecto-Ciberseguridad/miner/repos/vercel/pyproject.toml
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   vercel
#     #   vercel-workers
# blinker==1.9.0
#     # via flask
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via flask
# dramatiq==2.1.0
#     # via services-worker-wildcard-topic (pyproject.toml)
# flask==3.1.3
#     # via services-worker-wildcard-topic (pyproject.toml)
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# pydantic==2.13.4
#     # via
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# typing-extensions==4.15.0
#     # via
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   services-worker-wildcard-topic (pyproject.toml)
#     #   vercel
# websockets==16.0
#     # via vercel
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   vercel
#     #   vercel-workers
# blinker==1.9.0
#     # via flask
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via flask
# dramatiq==2.1.0
#     # via services-worker-multiple-topics (pyproject.toml)
# flask==3.1.3
#     # via services-worker-multiple-topics (pyproject.toml)
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# pydantic==2.13.4
#     # via
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# typing-extensions==4.15.0
#     # via
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   services-worker-multiple-topics (pyproject.toml)
#     #   vercel
# websockets==16.0
#     # via vercel
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   vercel
#     #   vercel-workers
# blinker==1.9.0
#     # via flask
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via flask
# dramatiq==2.1.0
#     # via services-worker-dramatiq (pyproject.toml)
# flask==3.1.3
#     # via services-worker-dramatiq (pyproject.toml)
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# pydantic==2.13.4
#     # via
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# typing-extensions==4.15.0
#     # via
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   services-worker-dramatiq (pyproject.toml)
#     #   vercel
# websockets==16.0
#     # via vercel
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   vercel
#     #   vercel-workers
# asgiref==3.11.1
#     # via django
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# django==6.0.5
#     # via services-worker-django-tasks (pyproject.toml)
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# pydantic==2.13.4
#     # via
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# sqlparse==0.5.5
#     # via django
# typing-extensions==4.15.0
#     # via
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   services-worker-django-tasks (pyproject.toml)
#     #   vercel
# websockets==16.0
#     # via vercel
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# amqp==5.3.1
#     # via kombu
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   vercel
#     #   vercel-workers
# billiard==4.2.4
#     # via celery
# blinker==1.9.0
#     # via flask
# cbor2==6.0.1
#     # via vercel
# celery==5.6.3
#     # via services-worker-celery (pyproject.toml)
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via
#     #   celery
#     #   click-didyoumean
#     #   click-plugins
#     #   click-repl
#     #   flask
# click-didyoumean==0.3.1
#     # via celery
# click-plugins==1.1.1.2
#     # via celery
# click-repl==0.3.0
#     # via celery
# flask==3.1.3
#     # via services-worker-celery (pyproject.toml)
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# kombu==5.6.2
#     # via celery
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# packaging==26.2
#     # via kombu
# prompt-toolkit==3.0.52
#     # via click-repl
# pydantic==2.13.4
#     # via
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dateutil==2.9.0.post0
#     # via celery
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# six==1.17.0
#     # via python-dateutil
# typing-extensions==4.15.0
#     # via
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# tzdata==2026.2
#     # via kombu
# tzlocal==5.3.1
#     # via celery
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   services-worker-celery (pyproject.toml)
#     #   vercel
# vine==5.1.0
#     # via
#     #   amqp
#     #   celery
#     #   kombu
# wcwidth==0.7.0
#     # via prompt-toolkit
# websockets==16.0
#     # via vercel
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   vercel
#     #   vercel-workers
# blinker==1.9.0
#     # via flask
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via flask
# dramatiq==2.1.0
#     # via services-worker-shared-source (pyproject.toml)
# flask==3.1.3
#     # via services-worker-shared-source (pyproject.toml)
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# pydantic==2.13.4
#     # via
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# typing-extensions==4.15.0
#     # via
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   services-worker-shared-source (pyproject.toml)
#     #   vercel
# websockets==16.0
#     # via vercel
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via services-python-cron-dynamic (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via services-python-cron-handlers (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via services-python-cron (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via backend-fastapi (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via api-fastapi (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via backend-fastapi (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# blinker==1.9.0
#     # via flask
# click==8.3.3
#     # via flask
# flask==3.1.3
#     # via py-api-flask (pyproject.toml)
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via backend-fastapi (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# blinker==1.9.0
#     # via flask
# click==8.3.3
#     # via flask
# flask==3.1.3
#     # via nested-python-version (pyproject.toml)
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# Error: Could not open file 'pyproject.toml': Could not parse 'pyproject.toml': Expected ']' at the end of a table declaration (at line 1, column 9)
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# blinker==1.9.0
#     # via flask
# click==8.3.3
#     # via flask
# flask==3.1.3
#     # via python-version-test (pyproject.toml)
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via priority-app (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# blinker==1.9.0
#     # via flask
# click==8.3.3
#     # via flask
# flask==3.1.3
#     # via uv-toml-test (pyproject.toml)
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# werkzeug==3.1.8
#     # via flask
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# click==8.3.3
#     # via uvicorn
# fastapi==0.136.1
#     # via simple-app (pyproject.toml)
# h11==0.16.0
#     # via uvicorn
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# uvicorn==0.46.0
#     # via simple-app (pyproject.toml)
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# click==8.3.3
#     # via uvicorn
# fastapi==0.136.1
#     # via nested-app (pyproject.toml)
# h11==0.16.0
#     # via uvicorn
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# uvicorn==0.46.0
#     # via nested-app (pyproject.toml)
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# ...
#     ...<3 lines>...
#         self.check_build_deps,
#     )
#   File "/workspaces/Proyecto-Ciberseguridad/.venv/lib/python3.14/site-packages/pip/_internal/operations/prepare.py", line 77, in _get_prepared_distribution
#     abstract_dist.prepare_distribution_metadata(
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         build_env_installer, build_isolation, check_build_deps
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/workspaces/Proyecto-Ciberseguridad/.venv/lib/python3.14/site-packages/pip/_internal/distributions/sdist.py", line 71, in prepare_distribution_metadata
#     self.req.prepare_metadata()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/workspaces/Proyecto-Ciberseguridad/.venv/lib/python3.14/site-packages/pip/_internal/req/req_install.py", line 530, in prepare_metadata
#     self.metadata_directory = generate_metadata(
#                               ~~~~~~~~~~~~~~~~~^
#         build_env=self.build_env,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#         backend=self.pep517_backend,
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         details=details,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "/workspaces/Proyecto-Ciberseguridad/.venv/lib/python3.14/site-packages/pip/_internal/operations/build/metadata.py", line 36, in generate_metadata
#     raise MetadataGenerationFailed(package_details=details) from error
# pip._internal.exceptions.MetadataGenerationFailed: metadata generation failed
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   starlette
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via prisma
# fastapi==0.136.1
#     # via fastapi-prisma-fixture (pyproject.toml)
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via prisma
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# jinja2==3.1.6
#     # via prisma
# markupsafe==3.0.3
#     # via jinja2
# nodeenv==1.10.0
#     # via prisma
# prisma==0.15.0
#     # via fastapi-prisma-fixture (pyproject.toml)
# pydantic==2.13.4
#     # via
#     #   fastapi
#     #   prisma
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via prisma
# starlette==1.0.0
#     # via fastapi
# tomlkit==0.14.0
#     # via prisma
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   prisma
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.121.1
#     # via 42-build-command (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==0.49.3
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via fixture-python314 (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.116.2
#     # via fixture-pyproject-fastapi (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==0.48.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# fastapi==0.136.1
#     # via fixture-python313 (pyproject.toml)
# idna==3.13
#     # via anyio
# pydantic==2.13.4
#     # via fastapi
# pydantic-core==2.46.4
#     # via pydantic
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   vercel
#     #   vercel-workers
#     #   vercel-workers (pyproject.toml)
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# h11==0.16.0
#     # via httpcore
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
#     #   vercel-workers (pyproject.toml)
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# pydantic==2.13.4
#     # via
#     #   vercel
#     #   vercel-workers
#     #   vercel-workers (pyproject.toml)
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
#     #   vercel-workers (pyproject.toml)
# typing-extensions==4.15.0
#     # via
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via pydantic
# vercel==0.5.8
#     # via
#     #   vercel-workers
#     #   vercel-workers (pyproject.toml)
# vercel-workers==0.0.22
#     # via vercel
# websockets==16.0
#     # via vercel
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# amqp==5.3.1
#     # via kombu
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   starlette
#     #   vercel
#     #   vercel-workers
# billiard==4.2.4
#     # via celery
# cbor2==6.0.1
#     # via vercel
# celery==5.6.3
#     # via celery-example (pyproject.toml)
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via
#     #   celery
#     #   click-didyoumean
#     #   click-plugins
#     #   click-repl
#     #   uvicorn
# click-didyoumean==0.3.1
#     # via celery
# click-plugins==1.1.1.2
#     # via celery
# click-repl==0.3.0
#     # via celery
# fastapi==0.136.1
#     # via celery-example (pyproject.toml)
# h11==0.16.0
#     # via
#     #   httpcore
#     #   uvicorn
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# kombu==5.6.2
#     # via celery
# packaging==26.2
#     # via kombu
# prompt-toolkit==3.0.52
#     # via click-repl
# pydantic==2.13.4
#     # via
#     #   fastapi
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dateutil==2.9.0.post0
#     # via celery
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# six==1.17.0
#     # via python-dateutil
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# tzdata==2026.2
#     # via kombu
# tzlocal==5.3.1
#     # via celery
# uvicorn==0.46.0
#     # via celery-example (pyproject.toml)
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   celery-example (pyproject.toml)
#     #   vercel
# vine==5.1.0
#     # via
#     #   amqp
#     #   celery
#     #   kombu
# wcwidth==0.7.0
#     # via prompt-toolkit
# websockets==16.0
#     # via vercel
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   starlette
#     #   vercel
#     #   vercel-workers
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via uvicorn
# fastapi==0.136.1
#     # via basic (pyproject.toml)
# h11==0.16.0
#     # via
#     #   httpcore
#     #   uvicorn
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# pydantic==2.13.4
#     # via
#     #   fastapi
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# uvicorn==0.46.0
#     # via basic (pyproject.toml)
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   basic (pyproject.toml)
#     #   vercel
# websockets==16.0
#     # via vercel
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via
#     #   httpx
#     #   starlette
#     #   vercel
#     #   vercel-workers
# cbor2==6.0.1
#     # via vercel
# certifi==2026.4.22
#     # via
#     #   httpcore
#     #   httpx
# click==8.3.3
#     # via uvicorn
# dramatiq==2.1.0
#     # via dramatiq-example (pyproject.toml)
# fastapi==0.136.1
#     # via dramatiq-example (pyproject.toml)
# h11==0.16.0
#     # via
#     #   httpcore
#     #   uvicorn
# httpcore==1.0.9
#     # via httpx
# httpx==0.28.1
#     # via
#     #   vercel
#     #   vercel-workers
# idna==3.13
#     # via
#     #   anyio
#     #   httpx
# pydantic==2.13.4
#     # via
#     #   fastapi
#     #   vercel
#     #   vercel-workers
# pydantic-core==2.46.4
#     # via pydantic
# python-dotenv==1.2.2
#     # via
#     #   vercel
#     #   vercel-workers
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
# uvicorn==0.46.0
#     # via dramatiq-example (pyproject.toml)
# vercel==0.5.8
#     # via vercel-workers
# vercel-workers==0.0.22
#     # via
#     #   dramatiq-example (pyproject.toml)
#     #   vercel
# websockets==16.0
#     # via vercel
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# annotated-doc==0.0.4
#     # via fastapi
# annotated-types==0.7.0
#     # via pydantic
# anyio==4.13.0
#     # via starlette
# click==8.3.3
#     # via uvicorn
# fastapi==0.136.1
#     # via vercel-fastapi-starter (pyproject.toml)
# h11==0.16.0
#     # via uvicorn
# idna==3.13
#     # via anyio
# jinja2==3.1.6
#     # via vercel-fastapi-starter (pyproject.toml)
# markupsafe==3.0.3
#     # via jinja2
# pydantic==2.13.4
#     # via
#     #   fastapi
#     #   pydantic-settings
# pydantic-core==2.46.4
#     # via pydantic
# pydantic-settings==2.14.0
#     # via vercel-fastapi-starter (pyproject.toml)
# python-dotenv==1.2.2
#     # via pydantic-settings
# starlette==1.0.0
#     # via fastapi
# typing-extensions==4.15.0
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-core
#     #   typing-inspection
# typing-inspection==0.4.2
#     # via
#     #   fastapi
#     #   pydantic
#     #   pydantic-settings
# uvicorn==0.46.0
#     # via vercel-fastapi-starter (pyproject.toml)
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# anyio==4.13.0
#     # via starlette
# click==8.3.3
#     # via uvicorn
# h11==0.16.0
#     # via uvicorn
# idna==3.13
#     # via anyio
# markupsafe==3.0.3
#     # via werkzeug
# starlette==1.0.0
#     # via vercel-starlette-starter (pyproject.toml)
# uvicorn==0.46.0
#     # via vercel-starlette-starter (pyproject.toml)
# werkzeug==3.1.8
#     # via vercel-starlette-starter (pyproject.toml)
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# asgiref==3.11.1
#     # via django
# django==6.0.5
#     # via vercel-django-starter (pyproject.toml)
# sqlparse==0.5.5
#     # via django
# INFO | pyproject.toml detectado, generando requirements.txt temporal para Grype...
# #
# # This file is autogenerated by pip-compile with Python 3.14
# # by the following command:
# #
# #    pip-compile --output-file=requirements.txt --strip-extras pyproject.toml
# #
# blinker==1.9.0
#     # via flask
# click==8.3.3
#     # via flask
# flask==3.1.3
#     # via vercel-flask-starter (pyproject.toml)
# itsdangerous==2.2.0
#     # via flask
# jinja2==3.1.6
#     # via flask
# markupsafe==3.0.3
#     # via
#     #   flask
#     #   jinja2
#     #   werkzeug
# werkzeug==3.1.8
#     # via flask
# INFO | Manifests found in vercel: Cargo.lock, Cargo.toml, Gemfile, Gemfile.lock, Pipfile, Pipfile.lock, go.mod, go.sum, package-lock.json, package.json, requirements.txt, yarn.lock
# INFO | Running Grype on vercel...
# INFO | Parsing Grype output...
# INFO | Found 10147 matches in Grype output
# INFO | Parsed 10147 vulnerabilities total
# INFO | Raw Grype output saved to results/vercel-grype-raw.json
# INFO | Normalized analysis saved to results/vercel-grype.json
# INFO | Summary | total_repos=25 | repos_scanned=25 | files_generated=50 | skipped=0 | errors=0
